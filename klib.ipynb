# %% [markdown]
# <a href="https://colab.research.google.com/github/zinakhazaee/Libraries/blob/main/klib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install klib

# %%
import klib
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/New dataset/heart.csv')

# %%
klib.cat_plot(df)  # returns a visualization of the number and frequency of categorical features
# Out:
# GridSpec(6, 5)

# %%
klib.corr_mat(df)  # returns a color-encoded correlation matrix
# Out:
# <style type="text/css">
# #T_ae14a_row0_col0, #T_ae14a_row0_col1, #T_ae14a_row0_col3, #T_ae14a_row0_col5, #T_ae14a_row0_col6, #T_ae14a_row1_col0, #T_ae14a_row1_col1, #T_ae14a_row1_col2, #T_ae14a_row1_col3, #T_ae14a_row1_col5, #T_ae14a_row1_col6, #T_ae14a_row2_col1, #T_ae14a_row2_col2, #T_ae14a_row2_col4, #T_ae14a_row2_col5, #T_ae14a_row3_col0, #T_ae14a_row3_col1, #T_ae14a_row3_col3, #T_ae14a_row3_col5, #T_ae14a_row3_col6, #T_ae14a_row4_col2, #T_ae14a_row4_col4, #T_ae14a_row5_col0, #T_ae14a_row5_col1, #T_ae14a_row5_col2, #T_ae14a_row5_col3, #T_ae14a_row5_col5, #T_ae14a_row5_col6, #T_ae14a_row6_col0, #T_ae14a_row6_col1, #T_ae14a_row6_col3, #T_ae14a_row6_col5, #T_ae14a_row6_col6 {
#   color: None;
# }
# ...

# %%
klib.corr_plot(df)   # returns a color-encoded heatmap, ideal for correlations
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.corr_interactive_plot(df, split="neg").show()  # returns an interactive correlation plot using plotly
# Out:
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
klib.dist_plot(df)  # returns a distribution plot for every numeric feature
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
klib.missingval_plot(df)  # returns a figure containing information about missing values
# Out:
# No missing values found in the dataset.

# %%
klib.data_cleaning(df)  # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
# Out:
# Shape of cleaned data: (918, 12) - Remaining NAs: 0
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.06 MB (-75.0%)
#      age sex chest_pain_type  resting_bp  cholesterol  fasting_bs resting_ecg  \
# 0     40   M             ATA         140          289           0      Normal
# 1     49   F             NAP         160          180           0      Normal
# 2     37   M             ATA         130          283           0          ST
# 3     48   F             ASY         138          214           0      Normal
# 4     54   M             NAP         150          195           0      Normal
# ..   ...  ..             ...         ...          ...         ...         ...
# 913   45   M              TA         110          264           0      Normal
# ...

# %%
klib.clean_column_names(df)  # cleans and standardizes column names, also called inside data_cleaning()
# Out:
#      age sex chest_pain_type  resting_bp  cholesterol  fasting_bs resting_ecg  \
# 0     40   M             ATA         140          289           0      Normal
# 1     49   F             NAP         160          180           0      Normal
# 2     37   M             ATA         130          283           0          ST
# 3     48   F             ASY         138          214           0      Normal
# 4     54   M             NAP         150          195           0      Normal
# ..   ...  ..             ...         ...          ...         ...         ...
# 913   45   M              TA         110          264           0      Normal
# 914   68   M             ASY         144          193           1      Normal
# 915   57   M             ASY         130          131           0      Normal
# 916   57   F             ATA         130          236           0         LVH
# 917   38   M             NAP         138          175           0      Normal
#
# ...

# %%
klib.convert_datatypes(df)  # converts existing to more efficient dtypes, also called inside data_cleaning()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
klib.drop_missing(df)   # drops missing values, also called in data_cleaning()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
klib.mv_col_handling(df)  # drops features with high ratio of missing vals based on informational content
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
klib.pool_duplicate_subsets(df) # pools subset of cols based on duplicates with min. loss of information
# Out:
#      Age  RestingBP  Cholesterol  MaxHR  pooled_vars
# 0     40        140          289    172            0
# 1     49        160          180    156            1
# 2     37        130          283     98            2
# 3     48        138          214    108            3
# 4     54        150          195    122            4
# ..   ...        ...          ...    ...          ...
# 913   45        110          264    132          913
# 914   68        144          193    141          914
# 915   57        130          131    115          737
# 916   57        130          236    174          916
# 917   38        138          175    173            4
#
# [918 rows x 5 columns]
